# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
# Задача 1
# Проведено 4 эксперимента. Для каждого построить график и посчитать коэффициенты
# корреляции Пирсона.

# %%
x = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68])

np.corrcoef(x, y)
# Out:
# array([[1.        , 0.81642052],
#        [0.81642052, 1.        ]])

# %%
plt.scatter(x, y)
plt.title('r= 0,81642052 (значение коэффициента)')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
y2 = np.array([9.14, 8.14, 8.74,8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])

np.corrcoef(x, y2)
# Out:
# array([[1.        , 0.81623651],
#        [0.81623651, 1.        ]])

# %%
plt.scatter(x, y2)
plt.title('r= 0,81623651 (значение коэффициента)')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
y3 = np.array([7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73])

np.corrcoef(x, y3)
# Out:
# array([[1.        , 0.81628674],
#        [0.81628674, 1.        ]])

# %%
plt.scatter(x, y3)
plt.title('r= 0,81628674 (значение коэффициента)')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x4 = np.array([8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8])
y4 = np.array([6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.5, 5.56, 7.91, 6.89])

np.corrcoef(x4, y4)
# Out:
# array([[1.        , 0.81652144],
#        [0.81652144, 1.        ]])

# %%
plt.scatter(x4, y4)
plt.title('r= 0,81652144 (значение коэффициента)')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x0 = np.array([ 10, 8, 13, 9, 11, 14, 6, 4, 12, 7,5, 15, 16, 18 ])
y0 = np.array([ 9.14, 8.14, 8.74,8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74, 6.5, 5, 2.9])

np.corrcoef(x0, y0)
# Out:
# array([[1.        , 0.02245218],
#        [0.02245218, 1.        ]])

# %%
plt.scatter(x0, y0)
plt.title('r= 0,02245218 (значение коэффициента)')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Задача 2
# Провести двусторонний тест и ответить на вопрос, есть ли статистически значимые
# различия между средними 2х нормально распределенных генеральных совокупностей,
# представленных следующими независимыми выборками:
#  a = np.array([12, 10, 11, 19, 13, 11, 17, 15, 19, 14, 21, 18, 21, 11, 17, 14, 15, 17, 20, 19])
#  b = np.array([11, 13, 18, 15, 17, 18, 10, 21, 26, 15, 11, 12, 15, 17, 10, 18, 18, 12,21, 20])
# Уровень статистической значимости принять за 5%
# 1. Используйте функцию в Python:
# 2. Имея p-value из функции рассчитать наблюдаемое значение критерия.
# 3. Найти коэффициент корреляции Пирсона

# %%
a = np.array([12, 10, 11, 19, 13, 11, 17, 15, 19, 14, 21, 18, 21, 11, 17, 14, 15, 17, 20, 19])
b = np.array([11, 13, 18, 15, 17, 18, 10, 21, 26, 15, 11, 12, 15, 17, 10, 18, 18, 12,21, 20])

stats.ttest_ind(a, b)
# Out:
# Ttest_indResult(statistic=-0.1599663264228627, pvalue=0.8737549039369696)

# %%
# Вывод: Данные выборки друг от друга не отличаются, т.к. pvalue > a (0,05)

# %%
# Коэффициент корреляции Пирсона
np.corrcoef(a, b)
# Out:
# array([[1.        , 0.01847613],
#        [0.01847613, 1.        ]])

# %%
# Поиск наблюдаемого значения. Расчет вручную.
s1 = np.std(a, ddof=1)
print(f'Среднее квадратическое отклонение по выборке a (несмещенное): {s1}')

s2 = np.std(b, ddof=1)
print(f'Среднее квадратическое отклонение по выборке b (несмещенное): {s2}')
# Out:
# Среднее квадратическое отклонение по выборке a (несмещенное): 3.5850567051229985
# Среднее квадратическое отклонение по выборке b (несмещенное): 4.290748922483052

# %%
# Стандартная ошибка среднего
ZE = np.sqrt(s1**2/20 + s2**2/20)
print(f'Стандартная ошибка среднего: {ZE}')
# Out:
# Стандартная ошибка среднего: 1.250263130199736

# %%
print(f'Наблюдаемое значение: {(np.mean(a) - np.mean(b))/ZE}')
# Out:
# Наблюдаемое значение: -0.1599663264228627

# %%
# Задача 3. Используя функцию stats.ttest_ind, проведите односторонний тест. Проверить ,что мю 1 > мю 2

# %%
stats.ttest_ind(a, b,alternative='greater', equal_var = True)
# Out:
# Ttest_indResult(statistic=-0.1599663264228627, pvalue=0.5631225480315152)

# %%
# Задача 3. Используя функцию stats.ttest_ind, проведите односторонний тест. Проверить ,что мю 1 < мю 2

# %%
stats.ttest_ind(a, b,alternative='less', equal_var = True)
# Out:
# Ttest_indResult(statistic=-0.1599663264228627, pvalue=0.4368774519684848)

# %%
# Задача 4. Используя функцию stats.t.ppf найдите, расчетное значение Стьюдента
# Определите табличное значение критерия Стьюдента

# %%
stats.t.ppf(1-0.05/2, len(a)+len(b)-2)
# Out:
# 2.024394164575136

# %%
# Задачи на повторение
# Спортсмен стреляет по мишени, разделенной на три сектора. Вероятность попадания в 1й
# сектор = 0.4, во второй = 0.3. Какова вероятность попадания в 1 или 2й сектор?

# %%
0.4 + 0.3
# Out:
# 0.7

# %%
# Задачи на повторение
# В группе 21 студент: 5 отличников, 10 хорошистов, 6 слабых. На предстоящем
# экзамене отлично могут получить только отличники, хорошисты с равной
# вероятностью могут получить хорошо и отлично, слабые –с одинаоквой
# вероятностью могут получить хорошо, удовлетворительно и неуд. На экзамен
# вызывается наугад 1 студент. Какова вероятность, что он получит хорошо или
# отлично

# %%
# P = m/n 
m = 5*1 + 10*1 + 6*1/3
n = 21
P = m/n 
print(f'Вызванный студент может получить хорошо или отлично с вероятностью - {P}')
# Out:
# Вызванный студент может получить хорошо или отлично с вероятностью - 0.8095238095238095

# %%
# Задачи на повторение
# Некоторое изделие выпускается 2мя заводами. При этом объем продукции 2го завода в 3 раза
# превосходит объем продукции 1го. Доля брака у 1го -2%, у 2го -1%. Изделие выпущено
# заводами за одинаковый промежуток времени. Изделия перемешали и отправили в продажу.
# Какова вероятность, что приобретенное изделие со 2го завода, если оно бракованное

# Use формулу Байеса
# P(B/A) = P(A/B)*P(B) / P(A)
# P(A/B) = 1% = 0.01
# P(B) = 0.75  <= 1/4(доля 1го) + 3/4(доля 2го)
# P(A) = 0.01*0.75 + 0.02*0.25

# %%
PB = 0.75  
PA = 0.01*0.75 + 0.02*0.25
P = (0.01*PB)/PA
print(f'Вероятность = {P}')
# Out:
# Вероятность = 0.6
